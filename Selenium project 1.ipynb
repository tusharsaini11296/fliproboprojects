# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
driver = webdriver.Chrome("chromedriver.exe")

# %% [markdown]
# - Question 1

# %%
url = 'https://www.naukri.com/'
driver.get(url)

# %%
search_job = driver.find_element_by_id("qsb-keyword-sugg")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="15f02a741906cfb570bc96ae7e288968", element="82888fb0-1a79-449f-92ea-1dd19a0becfb")>

# %%
search_job.send_keys("Data Analyst")

# %%
search_loc = driver.find_element_by_id("qsb-location-sugg")
search_loc.send_keys('Banglore')

# %%
search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
experience_required=[]


title_tags=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in title_tags:
    job_title.append(i.text)
job_title
# Out:
# ['Data Scientist / Data Analyst -Business Analyst',
#  'Data Analyst,1',
#  'Junior Data Analyst',
#  'Data Analyst',
#  'Network Design & Data Analyst',
#  'Advanced Business Analyst I - Data Analytics',
#  'Advanced Business Analyst II - Data Analytics',
#  'Senior Data Analyst',
#  'Senior Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Data Analyst',
#  'Lead Data Analyst',
#  'Senior Data Analyst Python, ML - Bangalore',
#  'Data analysts',
#  'Data Analyst',
#  'Excel VBA Jobs Bangalore | VBA data analyst Jobs',
#  'Consultant - Data Analyst',
#  'Assistant Vice President - MIS & Reporting ( Business Data Analyst)',
#  'Senior Data Analyst']

# %%
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    job_location.append(i.text)
job_location
# Out:
# ['Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru(Sector 2 HSR Layout)',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Chennai, Bangalore/Bengaluru, Delhi / NCR',
#  'Bangalore/Bengaluru, Bangalore',
#  'Bangalore/Bengaluru',
#  'Lucknow, Bangalore/Bengaluru',
#  'Coimbatore, Bangalore/Bengaluru, Trivandrum/Thiruvananthapuram',
#  'Bangalore/Bengaluru',
#  'Mumbai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
company_name
# Out:
# ['Inflexion Analytix Private Limited',
#  'Epsilon',
#  '(192 Reviews)',
#  'Simplilearn',
#  '(152 Reviews)',
#  'Flipkart',
#  '(3391 Reviews)',
#  'Dell International Services India Private Limited',
#  '(1775 Reviews)',
#  'Novo Nordisk India',
#  '(367 Reviews)',
#  'Novo Nordisk India',
#  '(367 Reviews)',
#  'Aritha Consulting Services Pvt. Ltd.',
#  'Publicis Groupe',
#  '(64 Reviews)',
#  'Novel Office',
#  'CoinSwitch.co',
#  'Harman Connected Services Corporation India Pvt.',
#  '(595 Reviews)',
#  'European Company',
#  '2coms',
#  'IBM India Pvt. Limited',
#  '(9977 Reviews)',
#  'CARNATION INFOTECH PRIVATE LIMITED',
#  'Mind Circus Innovation',
#  'Flipkart Internet Private Limited',
#  '(3391 Reviews)',
#  'INTERTRUSTVITEOS CORPORATE AND FUND SERVICES PVT. LTD.',
#  '(5 Reviews)',
#  'Harman Connected Services Corporation India Pvt.',
#  '(595 Reviews)']

# %%
len(company_name)
# Out:
# 32

# %%
experience=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience:
    experience_required.append(i.text)
experience_required
# Out:
# ['0-3 Yrs',
#  '0-2 Yrs',
#  '0-2 Yrs',
#  '3-8 Yrs',
#  '0-2 Yrs',
#  '7-12 Yrs',
#  '8-13 Yrs',
#  '2-4 Yrs',
#  '6-8 Yrs',
#  '0-3 Yrs',
#  '4-9 Yrs',
#  '5-7 Yrs',
#  '10-20 Yrs',
#  '2-7 Yrs',
#  '5-10 Yrs',
#  '0-5 Yrs',
#  '0-2 Yrs',
#  '0-2 Yrs',
#  '10-15 Yrs',
#  '2-7 Yrs']

# %%
Data_Analyst_jobs=pd.DataFrame({})
Data_Analyst_jobs['job_title']=job_title[0:10]
Data_Analyst_jobs['job_location']=job_location[0:10]
Data_Analyst_jobs['company_name']=company_name[0:10]
Data_Analyst_jobs['experience_required']=experience_required[0:10]
Data_Analyst_jobs
# Out:
#                                          job_title  \
# 0  Data Scientist / Data Analyst -Business Analyst
# 1                                   Data Analyst,1
# 2                              Junior Data Analyst
# 3                                     Data Analyst
# 4                    Network Design & Data Analyst
# 5     Advanced Business Analyst I - Data Analytics
# 6    Advanced Business Analyst II - Data Analytics
# 7                              Senior Data Analyst
# 8                              Senior Data Analyst
# 9                                     Data Analyst
#
#                                         job_location  \
# 0  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 1                                Bangalore/Bengaluru
# 2           Bangalore/Bengaluru(Sector 2 HSR Layout)
# 3                                Bangalore/Bengaluru
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# - Question 2

# %%
driver=webdriver.Chrome("chromedriver.exe") 
url = "https://www.naukri.com/"
driver.get(url)


search_field_designation=driver.find_element_by_id("qsb-keyword-sugg")
search_field_designation.send_keys("Data Scientist")

search_field_location=driver.find_element_by_id('qsb-location-sugg')
search_field_location.send_keys("Bangalore")

search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()

# %%
job_title=[]
job_location=[]
company_name=[]
job_description=[]

titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    job_title.append(i.text)
job_title
# Out:
# ['Ignitarium is hiring For Senior Data Scientist, Bangalore / Kochi',
#  'Data Scientist / Data Analyst -Business Analyst',
#  'Data Scientist',
#  'Senior Data Scientist For advisory/ teaching/ projects role Remote',
#  'Senior Data Scientist',
#  'Sr. Data Scientist',
#  'Sr . Data Scientist',
#  'Lead Data Scientist',
#  'Lead Data Scientist',
#  'Senior Data Scientist',
#  'Lead Data Scientist',
#  'Data Scientist',
#  'NielsenIQ Applied Data Scientist (Azure/Python/Spark)',
#  'Data Scientist II',
#  'Data Scientist',
#  'Data Scientist',
#  'Data Scientist',
#  'Senior Data Scientist',
#  'Data Scientist',
#  'Data Scientist']

# %%
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    job_location.append(i.text)
job_location
# Out:
# ['Kochi/Cochin, Ernakulam, Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Hyderabad/Secunderabad, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Hyderabad/Secunderabad, Pune, Chennai, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru',
#  'Noida, Bangalore/Bengaluru',
#  'Bangalore/Bengaluru']

# %%
companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
company_name
# Out:
# ['Ignitarium Technology Solutions Private Limited',
#  '(13 Reviews)',
#  'Inflexion Analytix Private Limited',
#  'Flipkart Internet Private Limited',
#  '(3391 Reviews)',
#  'Shikvix LLC',
#  'Qburst Technologies Pvt Ltd',
#  '(84 Reviews)',
#  'Neustar MarketShare',
#  '(16 Reviews)',
#  'Target Corporation India Pvt Ltd',
#  '(245 Reviews)',
#  'Gojek Tech',
#  'GO-JEK India',
#  '(6 Reviews)',
#  'Flipkart Internet Private Limited',
#  '(3391 Reviews)',
#  'bd',
#  '(44 Reviews)',
#  'Cardinal Drugs Ltd.',
#  'NielsenIQ',
#  '(19 Reviews)',
#  'ANI Technologies Pvt Ltd (Olacabs)',
#  '(1218 Reviews)',
#  'NHANCENOW',
#  '(2 Reviews)',
#  'Neustar MarketShare',
#  '(16 Reviews)',
#  'Fujitsu Consulting India Pvt. Ltd.',
#  '(654 Reviews)',
#  'Bigshyft Hiring for Bidgely',
#  'Oracle India Pvt. Ltd.',
#  '(1921 Reviews)',
#  'IBM India Pvt. Limited',
#  '(9977 Reviews)']

# %%
urls=[i.get_attribute("href")for i in driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")]
for url in urls[0:10]:
    try:
        
        driver.get(url)
        raw_description=driver.find_element_by_xpath("//section[@class='job-desc']/div[1]").text
        description=raw_description.replace("Contact Person","@@@@@")
        description= description.split("@@@@@")
        job_description.append(description[0])
    except NoSuchElementException :
        job_description.append("---")
job_description
# Out:
# ['Senior Data Scientist\n\nPlease find the JD below:\nData Engineering experience using Python.\nExperience in NumPy, Scikit-learn, Scipy, Pandas etc.\nHand on experience in classification, regression, clustering, machine learning algorithms.\nWorking experience with any of the object-oriented/object function scripting languages: Python, Java, Scala, Shell, .NET scripting.\nExperience in any of the cloud platforms like AWS, Azure, GCP\n\nLet me know your interest. Please mail your profile to arathy.rajkumar@ignitarium.com',
# ...

# %%
Data_scientist_jobs=pd.DataFrame({})
Data_scientist_jobs['job_title']=job_title[0:10]
Data_scientist_jobs['job_location']=job_location[0:10]
Data_scientist_jobs['company_name']=company_name[0:10]
Data_scientist_jobs['job_description']=job_description[0:10]
Data_scientist_jobs
# Out:
#                                            job_title  \
# 0  Ignitarium is hiring For Senior Data Scientist...
# 1    Data Scientist / Data Analyst -Business Analyst
# 2                                     Data Scientist
# 3  Senior Data Scientist For advisory/ teaching/ ...
# 4                              Senior Data Scientist
# 5                                 Sr. Data Scientist
# 6                                Sr . Data Scientist
# 7                                Lead Data Scientist
# 8                                Lead Data Scientist
# 9                              Senior Data Scientist
#
#                                         job_location  \
# 0       Kochi/Cochin, Ernakulam, Bangalore/Bengaluru
# 1  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 2                                Bangalore/Bengaluru
# 3  Hyderabad/Secunderabad, Chennai, Bangalore/Ben...
# 4                                Bangalore/Bengaluru
# 5                                Bangalore/Bengaluru
# ...

# %% [markdown]
# - Question 3

# %%
driver=webdriver.Chrome("chromedriver.exe") 

url = "https://www.naukri.com/"
driver.get(url)

search_field_designation=driver.find_element_by_id("qsb-keyword-sugg")   
search_field_designation.send_keys("Data Scientist")


search_button=driver.find_element_by_xpath("//div[@class='search-btn']/button")
search_button.click()



job_title=[]
job_location=[]
company_name=[]
experience_required=[]

# %%
location_button=driver.find_element_by_xpath("//label[@for='chk-Delhi / NCR-cityTypeGid-']/i")
location_button.click()

# %%
salary_button=driver.find_element_by_xpath("//label[@for='chk-3-6 Lakhs-ctcFilter-']/i")
salary_button.click()

# %%
titles=driver.find_elements_by_xpath("//a[@class='title fw500 ellipsis']")
for i in titles:
    job_title.append(i.text)
    
    
locations=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi location']/span[1]")
for i in locations:
    job_location.append(i.text)
    

companies=driver.find_elements_by_xpath("//div[@class='mt-7 companyInfo subheading lh16']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
        
        
experience=driver.find_elements_by_xpath("//li[@class='fleft grey-text br2 placeHolderLi experience']/span[1]")
for i in experience:
    experience_required.append(i.text)
    
    

Data_scientist_jobs=pd.DataFrame({})
Data_scientist_jobs['job_title']=job_title[0:11]
Data_scientist_jobs['job_location']=job_location[0:11]
Data_scientist_jobs['company_name']=company_name[0:11]
Data_scientist_jobs['experience_required']=experience_required[0:11]
Data_scientist_jobs
# Out:
#                                             job_title  \
# 0       Data Scientist/Data Analyst /Business Analyst
# 1                We are hiring- Data Scientist- Noida
# 2   Only Fresher / Data Scientist / Data Analyst /...
# 3                               Senior Data Scientist
# 4               Team Leader Operations/Data Scientist
# 5                                      Data Scientist
# 6                       Data Scientist (Early Joiner)
# 7              Data Scientist - Machine Learning/ NLP
# 8                  Advanced Analytics -Data Scientist
# 9                                      Data Scientist
# 10                    Data Scientist || Python || C2H
#
#                                          job_location  \
# 0               Pune, Delhi / NCR, Mumbai (All Areas)
# 1                                         Delhi / NCR
# 2                   Noida, Greater Noida, Delhi / NCR
# 3   Hyderabad/Secunderabad, Gurgaon/Gurugram, Bang...
# ...

# %% [markdown]
# - Question 4

# %%
driver=webdriver.Chrome("chromedriver.exe") 


url = "https://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
import requests
page = requests.get('https://www.glassdoor.co.in/index.htm')
page
# Out:
# <Response [403]>

# %% [markdown]
# - As I am not getting response 200, So I didn't attempt this question

# %% [markdown]
# - Question 5

# %%
import time
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(4)

url = "https://www.glassdoor.co.in/index.htm"
driver.get(url)

# %%
# Now entering “Data Scientist” in “SJob Title, Keywords or Company” field and enter “Noida” in “location” field.

search_field_designation=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[1]//div[1]//input")  #job search bar
search_field_designation.send_keys("Data Scientist")

time.sleep(2)
# clearing job location search_bar
from selenium.webdriver.common.keys import Keys
for i in range(9):
    driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input").send_keys(Keys.BACK_SPACE)

#location search bar
search_field_location=driver.find_element_by_xpath("//div[@class='d-flex flex-row align-items-center']//div[3]//div[1]//input")  
search_field_location.send_keys("Noida")

time.sleep(2)
# Select salary option
option = driver.find_element_by_xpath("//div[@class='selectedLabel']")
option.click()
time.sleep(2)
salary_option = driver.find_element_by_xpath("//div[@class='dropDownOptionsContainer']//ul//li[3]")
salary_option.click()

time.sleep(2)
# clicking the search button
search_button=driver.find_element_by_xpath("//button[@class='gd-ui-button ml-std col-auto SearchStyles__newSearchButton css-iixdfr']")
search_button.click()

# creating empty lists for scraping data
company_name=[]
min_salaries=[]
max_salaries=[]
average_salaries=[]
no_of_salaries=[]

# %%
companies=driver.find_elements_by_xpath("//h3[@class='m-0 css-g261rn']/a")
for i in companies:
    if i.text is None :
        company_name.append("--") 
    else:
        company_name.append(i.text)
company_name
# Out:
# ['IBM',
#  'Tata Consultancy Services',
#  'Accenture',
#  'Delhivery',
#  'Ericsson-Worldwide',
#  'UnitedHealth Group',
#  'Valiance Solutions',
#  'EXL Service',
#  'Optum',
#  'Optum Global Solutions',
#  'ZS Associates',
#  'Innovaccer',
#  'Cognizant Technology Solutions',
#  'OYO',
#  'Nagarro',
#  'dunnhumby',
#  'Vidooly Media Tech',
#  'Tech Mahindra',
#  'Bharti Airtel',
#  'R Systems']

# %%
min_salary=driver.find_elements_by_xpath("//div[@class='d-flex mt-xxsm css-79elbk epuxyqn0']/p[1]")
for i in min_salary:
    min_salaries.append(i.text)
min_salaries
# Out:
# ['₹6L',
#  '₹3L',
#  '₹6L',
#  '₹5L',
#  '₹4L',
#  '₹8L',
#  '₹5L',
#  '₹6L',
#  '₹8L',
#  '₹4L',
#  '₹2L',
#  '₹6L',
#  '₹8L',
#  '₹10L',
#  '₹4L',
#  '₹8L',
#  '₹12T',
#  '₹4L',
#  '₹6L',
#  '₹8L']

# %%
max_salary=driver.find_elements_by_xpath("//div[@class='d-flex mt-xxsm css-79elbk epuxyqn0']/p[2]")
for i in max_salary:
    max_salaries.append(i.text)
max_salaries
# Out:
# ['₹27L',
#  '₹13L',
#  '₹22L',
#  '₹1Cr',
#  '₹16L',
#  '₹15L',
#  '₹15L',
#  '₹15L',
#  '₹20L',
#  '₹22L',
#  '₹18L',
#  '₹17L',
#  '₹13L',
#  '₹19L',
#  '₹16L',
#  '₹20L',
#  '₹63T',
#  '₹17L',
#  '₹29L',
#  '₹30L']

# %%
avg_salary=driver.find_elements_by_xpath("//div[@class='col-12 col-lg-4 px-lg-0 d-flex align-items-baseline']/h3")
for i in avg_salary:
    no_of_salaries.append(i.text)
no_of_salaries
# Out:
# ['₹9,00,000',
#  '₹6,15,289',
#  '₹11,63,336',
#  '₹12,18,244',
#  '₹7,39,238',
#  '₹13,00,000',
#  '₹8,63,750',
#  '₹11,10,000',
#  '₹14,23,677',
#  '₹13,28,697',
#  '₹11,42,356',
#  '₹12,09,040',
#  '₹10,09,021',
#  '₹12,58,227',
#  '₹9,92,632',
#  '₹10,55,478',
#  '₹34,157',
#  '₹10,54,402',
#  '₹16,00,000',
#  '₹18,40,134']

# %%
rating=driver.find_elements_by_xpath("//div[@class='d-flex align-items-center mt-xxsm']/span[1]")
for i in rating:
    average_salaries.append(i.text)
average_salaries
# Out:
# ['3.9',
#  '3.9',
#  '4',
#  '3.9',
#  '4',
#  '3.6',
#  '4.2',
#  '3.6',
#  '3.7',
#  '3.9',
#  '4',
#  '3.8',
#  '3.8',
#  '3.3',
#  '4',
#  '4.1',
#  '3.7',
#  '3.6',
#  '3.8',
#  '3.5']

# %%
Data_scientist_salaries=pd.DataFrame({})
Data_scientist_salaries['company name']=company_name[0:11]
Data_scientist_salaries['min_salary']=min_salaries[0:11]
Data_scientist_salaries['max_salary']=max_salaries[0:11]
Data_scientist_salaries['ratings']=average_salaries[0:11]
Data_scientist_salaries['Average_salary']=no_of_salaries[0:11]
Data_scientist_salaries
# Out:
#                  company name min_salary max_salary ratings Average_salary
# 0                         IBM        ₹6L       ₹27L     3.9      ₹9,00,000
# 1   Tata Consultancy Services        ₹3L       ₹13L     3.9      ₹6,15,289
# 2                   Accenture        ₹6L       ₹22L       4     ₹11,63,336
# 3                   Delhivery        ₹5L       ₹1Cr     3.9     ₹12,18,244
# 4          Ericsson-Worldwide        ₹4L       ₹16L       4      ₹7,39,238
# 5          UnitedHealth Group        ₹8L       ₹15L     3.6     ₹13,00,000
# 6          Valiance Solutions        ₹5L       ₹15L     4.2      ₹8,63,750
# 7                 EXL Service        ₹6L       ₹15L     3.6     ₹11,10,000
# 8                       Optum        ₹8L       ₹20L     3.7     ₹14,23,677
# 9      Optum Global Solutions        ₹4L       ₹22L     3.9     ₹13,28,697
# 10              ZS Associates        ₹2L       ₹18L       4     ₹11,42,356

# %% [markdown]
# - Questions 6

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.flipkart.com/"
driver.get(url)

# %%
search_bar=driver.find_element_by_class_name("_3704LK")
search_bar.send_keys('sunglasses')

button=driver.find_element_by_class_name('L0Z3Pu')
button.click()

brand=[]
description=[]
price=[]
discount=[]

# %%
for page in range(0,5):
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))

        

    brands=driver.find_elements_by_class_name('_2WkVRV')
    for i in brands:
        brand.append(i.text)
        
    desc=driver.find_elements_by_xpath('//a[@class="IRpwTa"]')
    for i in desc:
        description.append(i.text)
        
    prices=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in prices:
        price.append(i.text)
        
    disc=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']//span")
    for i in disc:
        discount.append(i.text)

# %%
df=pd.DataFrame({'Brand':brand[:100],
                'Description':description[:100],
                'Price':price[:100],
                'Discount':discount[:100]})
df
# Out:
#              Brand                                        Description Price  \
# 0         Fastrack  Mirrored, UV Protection Wayfarer Sunglasses (F...  ₹738
# 1            NuVew              UV Protection Aviator Sunglasses (58)  ₹215
# 2         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹733
# 3        ROYAL SON  UV Protection, Gradient Over-sized Sunglasses ...  ₹699
# 4         Fastrack      UV Protection Wayfarer Sunglasses (Free Size)  ₹539
# ..             ...                                                ...   ...
# 95       Elligator  UV Protection, Gradient Butterfly, Shield Sung...  ₹312
# 96       ROYAL SON               Gradient Rectangular Sunglasses (56)  ₹399
# 97  ROZZETTA CRAFT  UV Protection, UV Protection Retro Square Sung...  ₹399
# 98    IRUS by IDEE      UV Protection Wayfarer Sunglasses (Free Size)  ₹606
# 99  ROZZETTA CRAFT          UV Protection Rectangular Sunglasses (56)  ₹349
#
#    Discount
# 0   26% off
# 1   72% off
# 2   18% off
# ...

# %% [markdown]
# - Question 7

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.flipkart.com/apple-iphone-11-black-64-gb-includes-earpods-power-adapter/product-reviews/itm0f37c2240b217?pid=MOBFKCTSVZAXUHGR&lid=LSTMOBFKCTSVZAXUHGREPBFGI&marketplace=FLIPKART"
driver.get(url)

# %%
short_review=[]
complete_review=[]
stars=[]

for i in range(10):
    url=driver.find_element_by_xpath("//a[@class='ge-49M']").get_attribute('href')
    driver.get(url)
    
    for j in driver.find_elements_by_xpath("//div[@class='_3LWZlK _1BLPMq']"):
        stars.append(j.text)
        
    for m in driver.find_elements_by_xpath("//p[@class='_2-N8zT']"):
        short_review.append(m.text)
        
    for a in driver.find_elements_by_xpath("//div[@class='t-ZTKy']/div/div"):
        complete_review.append(a.text)

# %%
df=pd.DataFrame({'Number of Stars': stars,
                'Short Review': short_review,
               'Full Review': complete_review})
df
# Out:
#    Number of Stars        Short Review  \
# 0                5    Perfect product!
# 1                5   Worth every penny
# 2                5  Highly recommended
# 3                5    Perfect product!
# 4                5      Simply awesome
# ..             ...                 ...
# 95               5       Great product
# 96               4         Good choice
# 97               5   Worth every penny
# 98               5  Highly recommended
# 99               5    Perfect product!
#
#                                           Full Review
# 0   Value for money❤️❤️\nIts awesome mobile phone ...
# 1   Best budget Iphone till date ❤️ go for it guys...
# 2   What a camera .....just awesome ..you can feel...
# 3   Iphone is just awesome.. battery backup is ver...
# 4   Excellent camera, good performance, no lag. Th...
# ..                                                ...
# 95  Amazing Powerful and Durable Gadget.\n\nI’m am...
# ...

# %% [markdown]
# - Question 8

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.flipkart.com/"
driver.get(url)

# %%
search_column=driver.find_element_by_class_name("_3704LK")
search_column.send_keys('sneakers')


button=driver.find_element_by_class_name('L0Z3Pu')
button.click()

brand=[]
description=[]
price=[]
discount=[]

# %%
for page in range(0,4):
    next_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(next_button[1].get_attribute('href'))
    except:
        driver.get(next_button[0].get_attribute('href'))
    
    
    brands=driver.find_elements_by_class_name('_2WkVRV')
    for i in brands:
        brand.append(i.text)
        
    prices=driver.find_elements_by_xpath("//div[@class='_30jeq3']")
    for i in prices:
        price.append(i.text)
        
    disc=driver.find_elements_by_xpath("//div[@class='_3Ay6Sb']//span")
    for i in disc:
        discount.append(i.text)
        
 

urls = []

for page in range(0,4):
    
    product_url = driver.find_elements_by_xpath("//a[@class='_2UzuFa']")
    for i in product_url:
        urls.append(i.get_attribute('href'))
    
    nxt_button=driver.find_elements_by_xpath("//a[@class='_1LKTO3']")
    try:
        driver.get(nxt_button[1].get_attribute('href'))
    except:
        driver.get(nxt_button[0].get_attribute('href'))
        

for i in urls:
    driver.get(i)
    desc=driver.find_elements_by_xpath('//span[@class="B_NuCI"]')
    for i in desc:
        description.append(i.text)

# %%
df=pd.DataFrame({'Brand':brand[:100],
                'Description':description[:100],
                'Price':price[:100],
                'Discount':discount[:100]})
df
# Out:
#                   Brand                                        Description  \
# 0          Jack Diamond            SM-322 Sneakers For Men  (Navy, Yellow)
# 1               Jokatoo  Combo Pack of 5 Casual Shoes Loafers Sneakers ...
# 2                 ASIAN       casual shoe for men Sneakers For Men  (Blue)
# 3                Chevit  Combo Pack of 4 Casual Sneakers With Sneakers ...
# 4   World Wear Footwear  Men's Ultraforce Mid-top Athletic-Inspired Ret...
# ..                  ...                                                ...
# 95         Robbie jones  Combo Shoes Pack of 2 latest & Affordable casu...
# 96               REEBOK                           Sneakers For Men  (Blue)
# 97      U.S. POLO ASSN.          Streetballer Mid Sneakers For Men  (Navy)
# 98                 PUMA              SM-360 Sneakers For Men  (Red, Black)
# 99                Birde  Luxury Fashionable Breathable White shoes for ...
#
#      Price Discount
# 0     ₹399  60% off
# 1     ₹418  71% off
# ...

# %% [markdown]
# - Question 9

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.myntra.com/shoes%22"
driver.get(url)

# %%
price_button = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[5]/ul/li[2]/label/div")
price_button.click()


black_color_button = driver.find_element_by_xpath("/html/body/div[2]/div/div[1]/main/div[3]/div[1]/section/div/div[6]/ul/li[1]/label/div")
black_color_button.click()

shoe_names=[]
short_desc=[]
price=[]
page_urls = []
s_desc=[]

# %%
nxt_page = driver.find_elements_by_xpath("//li[@class='pagination-number']/a")
for i in nxt_page:
    page_urls.append(i.get_attribute('href'))
    

for url in page_urls[:3]:
    driver.get(url)
    Names=driver.find_elements_by_xpath("//div[@class='product-productMetaInfo']/h3")
    for i in Names:
        shoe_names.append(i.text)
        
        
    desc=driver.find_elements_by_xpath("//div[@class='product-productMetaInfo']/h4")
    for i in desc:
        s_desc.append(i.text)
    #As, the s_desc list contain blank description in every alternate index, so removing the blank or null description
    for j in range(0,len(s_desc),2):
        short_desc.append(s_desc[j])
        
    rs=driver.find_elements_by_xpath("//div[@class='product-price']")
    for i in rs:
        price.append(i.text)

# %%
df=pd.DataFrame({'Brand': shoe_names[:100],
                 'Short-description': short_desc[:100],
                 'Price': price[:100]})
df
# Out:
#                     Brand                  Short-description  \
# 0                 ZAPATOZ                Women Walking Shoes
# 1                   Sparx                  Men Running Shoes
# 2                    ALDO                       Men Sneakers
# 3             one8 x PUMA              Men Dart IDP Sneakers
# 4                   Sparx                  Men Running Shoes
# ..                    ...                                ...
# 95                  Sparx                  Men Running Shoes
# 96                 Reebok  Unisex Kids Woven Design Sneakers
# 97  HRX by Hrithik Roshan        Women Sneakers Casual Shoes
# 98           Kook N Keech               Women Solid Sneakers
# 99                   Puma                Women T-Strap Flats
#
#                           Price
# 0       Rs. 599Rs. 999(40% OFF)
# 1     Rs. 1245Rs. 1399(11% OFF)
# 2                      Rs. 9999
# 3     Rs. 2999Rs. 3999(25% OFF)
# 4       Rs. 986Rs. 1049(6% OFF)
# ..                          ...
# ...

# %% [markdown]
# - Question 10

# %%
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(3)

url = "https://www.amazon.in/ref=nav_logo"
driver.get(url)

# %%
search_bar = driver.find_element_by_id("twotabsearchtextbox") 
search_bar.send_keys("laptops")    

search_button = driver.find_element_by_xpath('//span[@id="nav-search-submit-text"]')
search_button.click()

# %%
filter_button=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in filter_button:
    if i.text=='Intel Core i7':
        i.click()
        break

# %%
filter_button=driver.find_elements_by_xpath("//a[@class='a-link-normal s-navigation-item']/span")
for i in filter_button:
    if i.text=='Intel Core i9':
        i.click()
        break

# %%
Title=[]
Ratings=[]
price=[]


titles=driver.find_elements_by_xpath("//span[@class='a-size-medium a-color-base a-text-normal']")
for i in titles[:10]:
    Title.append(i.text)
    
    
prices=driver.find_elements_by_xpath("//span[@class='a-price-whole']")
for i in prices[:10]:
    price.append(i.text)

# %%
urls=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
URL=[]
for i in urls[:10]:
    URL.append(i.get_attribute('href'))

    
    
for url in URL:
    driver.get(url)
    try:                                                  
        rating=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
        Ratings.append(rating.text)
        
    except NoSuchElementException:
        Ratings.append("NO rating")

# %%
df=pd.DataFrame({'Title':Title[:10],
                'Price':price[:10],
                'Ratings':Ratings[:10]})
df
# Out:
#                                                Title   Price       Ratings
# 0  HP Pavilion x360 (2021) 14" (35.56cms) FHD Tou...  78,993    4 out of 5
# 1  HP Pavilion (2021) Thin & Light 11th Gen Core ...  84,126  4.5 out of 5
# 2  Mi Notebook Horizon Edition 14 Intel Core i7-1...  59,999  4.4 out of 5
# 3  Dell G3 3500 Gaming Laptop 15.6" (39.62cms) FH...  86,390  4.2 out of 5
# 4  Lenovo IdeaPad Flex 5 11th Gen Intel Core i7 1...  83,990    4 out of 5
# 5  Life Digital Laptop 15.6-inch (39.62 cms) (Int...  40,932  3.7 out of 5
# 6  Dell 14 (2021) i7-1165G7 2in1 Touch Screen Lap...  91,790  4.2 out of 5
# 7  Life Digital Laptop 15.6-inch (39.62 cms) (Int...  46,322  3.2 out of 5
# 8  MSI GF63 Thin 10SCSR-019IN Intel Core i7-10750...  84,990  2.9 out of 5
# 9  Lenovo Legion Y540 Intel Core i7 9th Gen 15.6”...  69,990  4.3 out of 5
